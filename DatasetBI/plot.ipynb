# %%
import pandas as pd 
import plotly_express as px

# %% [markdown]
# ## Mungitura

# %%
df = pd.read_csv("Mungitura.csv")
# Out:
# /var/folders/48/tzp62xjn58bb_nw1n30kx0sh0000gn/T/ipykernel_22042/2958701052.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Mungitura.csv")

# %%
df.drop(columns=["Unnamed: 0","OCC(*1000 Cell/ml)"],inplace=True)

# %%
df['MS/MP'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Ora inizio', 'Numero animale', 'Gruppo', 'MS/MP', 'Azione',
#        'Durata (MM:SS)', 'Produzione (kg)', 'Numero mungitura', 'Kick-off',
#        'Incompleto', 'Capezzoli non trovati', 'Mammella', 'Capezzolo',
#        'Flusso AS', 'Flusso AD', 'Flusso PS', 'Flusso PD', 'Sangue AS',
#        'Sangue AD', 'Sangue PS', 'Sangue PD', 'Conducibilità AS',
#        'Conducibilità AD', 'Conducibilità PS', 'Conducibilità PD', 'Utente',
#        'Destinazione latte', 'Motivo separazione', 'PicchiFlusso AS',
#        'PicchiFlusso AD', 'PicchiFlusso PS', 'PicchiFlusso PD',
#        'Produzione AS', 'Produzione AD', 'Produzione PS', 'Produzione PD'],
#       dtype='object')

# %%
cat_cols = df.select_dtypes(include=['object'])

# %%
cat_cols
# Out:
#               Ora inizio    Gruppo MS/MP     Azione Durata (MM:SS)  \
# 0       31/08/2020 23:59     VMS 3   MS3  Mungitura          05:29
# 1       31/08/2020 23:57     VMS 1   MS1  Mungitura          12:09
# 2       31/08/2020 23:55  Asciutte   MS2  Mungitura          07:14
# 3       31/08/2020 23:54  Asciutte   MS3  Mungitura          04:48
# 4       31/08/2020 23:53  Asciutte   MS4  Mungitura          09:57
# ...                  ...       ...   ...        ...            ...
# 289971  31/10/2020 00:09     VMS 2   MS1  Mungitura          10:09
# 289972  31/10/2020 00:03  Asciutte   MS3  Mungitura          08:01
# 289973  31/10/2020 00:03     VMS 1   MS1  Mungitura          05:56
# 289974  31/10/2020 00:02  Asciutte   MS2  Mungitura          03:11
# 289975  31/10/2020 00:00     VMS 4   MS4  Mungitura          10:22
#
#        Produzione (kg) Kick-off Incompleto Capezzoli non trovati Capezzolo  \
# 0                 5,31      NaN        NaN                   NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289976 entries, 0 to 289975
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Ora inizio             289976 non-null  object
#  1   Numero animale         289975 non-null  float64
#  2   Gruppo                 262541 non-null  object
#  3   MS/MP                  289825 non-null  object
#  4   Azione                 289975 non-null  object
#  5   Durata (MM:SS)         289975 non-null  object
#  6   Produzione (kg)        282405 non-null  object
#  7   Numero mungitura       282405 non-null  float64
#  8   Kick-off               10377 non-null   object
#  9   Incompleto             16266 non-null   object
#  10  Capezzoli non trovati  69750 non-null   object
#  11  Mammella               282405 non-null  float64
#  12  Capezzolo              32227 non-null   object
#  13  Flusso AS              276348 non-null  object
# ...

# %%
df.hist(figsize=(5,5))
# Out:
# array([[<AxesSubplot: title={'center': 'Unnamed: 0'}>,
#         <AxesSubplot: title={'center': 'Numero animale'}>,
#         <AxesSubplot: title={'center': 'Numero mungitura'}>],
#        [<AxesSubplot: title={'center': 'Mammella'}>,
#         <AxesSubplot: title={'center': 'Sangue AS'}>,
#         <AxesSubplot: title={'center': 'Sangue AD'}>],
#        [<AxesSubplot: title={'center': 'Sangue PS'}>,
#         <AxesSubplot: title={'center': 'Sangue PD'}>, <AxesSubplot: >]],
#       dtype=object)
