# %%
import pandas as pd
df_1=pd.read_csv("new_mungitura.csv")
# Out:
# C:\Users\digig\AppData\Local\Temp\ipykernel_5184\4198939064.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1=pd.read_csv("new_mungitura.csv")

# %%
df_1.to_csv("new_mungitura2.csv",sep=";",decimal=",")

# %%
df_2=pd.read_csv("new_traffico_animali.csv")
df_2.to_csv("new_traffico1.csv",sep=";",decimal=",")
# Out:
# C:\Users\digig\AppData\Local\Temp\ipykernel_5184\2475647443.py:1: DtypeWarning: Columns (0,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2=pd.read_csv("new_traffico_animali.csv")

# %%
df_2
# Out:
#                                            Numero animale Nome gruppo  \
# 0                                                     980    Asciutte
# 1                                                       0           0
# 2                                                     980    Asciutte
# 3                                                       0           0
# 4                                                     980    Asciutte
# ...                                                   ...         ...
# 872745                                                  0           0
# 872746                                                  0           0
# 872747                                                  0           0
# 872748                                                  0           0
# 872749  PRECEDENTEMENTE IL GRUPPO E' COMPOSTO DA MANZE...         NaN
#
#                 Data/Ora Area precedente Tempo nell'area (hh:mm)  \
# ...
